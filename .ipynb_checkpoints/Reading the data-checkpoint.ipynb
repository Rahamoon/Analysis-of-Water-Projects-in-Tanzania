# %% [markdown]
# # Reading and checking the data
#
# Let's start by reading the data into a pandas DataFrame.

# %%
import settings
import os

import pandas as pd

data_values = pd.read_csv(os.path.join(settings.DATA_DIR, "Training set values.csv"), index_col =0)
data_labels = pd.read_csv(os.path.join(settings.DATA_DIR, "Training set labels.csv"), index_col =0)
test_values = pd.read_csv(os.path.join(settings.DATA_DIR, "Test set values.csv"), index_col =0)

# %% [markdown]
# I will then verify the shape and the first rows of each DataFrame.

# %%
print data_values.shape
data_values.head()
# Out:
# (59400, 39)
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin          ...          payment_type  \
# id                                      ...
# ...

# %%
print data_labels.shape
data_labels.head()
# Out:
# (59400, 1)
#          status_group
# id
# 69572      functional
# 8776       functional
# 34310      functional
# 67743  non functional
# 19728      functional

# %%
print test_values.shape
test_values.head()
# Out:
# (14850, 39)
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 50785         0.0    2013-02-04                    Dmdd        1996
# 51630         0.0    2013-02-04  Government Of Tanzania        1569
# 17168         0.0    2013-02-01                     NaN        1567
# 45559         0.0    2013-01-22              Finn Water         267
# 49871       500.0    2013-03-27                  Bruder        1260
#
#         installer  longitude   latitude                 wpt_name  num_private  \
# id
# 50785        DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 51630         DWE  36.656709  -3.309214                  Kimnyak            0
# 17168         NaN  34.767863  -5.004344           Puma Secondary            0
# 45559  FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 49871      BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
#
# ...

# %% [markdown]
# ** In order to preprocess the data , I join the training and the test sets together, so I combine them into all_data. I add an extra column 'subset', so that I can split the data later on. **

# %%
data_values['subset'] = "training"
test_values['subset'] = "test"

all_data = pd.concat([data_values, test_values])

# %%
print all_data.shape
print all_data[all_data['subset'] == "training"].shape
print all_data[all_data['subset'] == "test"].shape
all_data.iloc[[0,1,2,-3,-2,-1]]
# Out:
# (74250, 40)
# (59400, 40)
# (14850, 40)
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 69572      6000.0    2011-03-14                   Roman        1390
# 8776          0.0    2013-03-06                 Grumeti        1399
# 34310        25.0    2013-02-25            Lottery Club         686
# 28749         0.0    2013-03-04                     NaN        1476
# 33492         0.0    2013-02-18                 Germany         998
# 68707         0.0    2013-02-13  Government Of Tanzania         481
#
#           installer  longitude   latitude          wpt_name  num_private  \
# id
# 69572         Roman  34.938093  -9.856322              none            0
# 8776        GRUMETI  34.698766  -2.147466          Zahanati            0
# 34310  World vision  37.460664  -3.821329       Kwa Mahundi            0
# 28749           NaN  34.739804  -4.585587           Bwawani            0
# 33492           DWE  35.432732 -10.584159          Kwa John            0
# ...

# %%
all_data.to_csv('processed/all_data.csv', encoding='utf-8')
